# %% [markdown]
# <a href="https://colab.research.google.com/github/nickmalleson/GEOG5415M/blob/main/GEOG5415_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GEOG5415 Week 9 Practical
#
# This is to experiment with uploading and reading data to/from GitHub

# %%
# Code will go here
print("Hello, world")
